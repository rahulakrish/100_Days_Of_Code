# %% [markdown]
# #TODO: Create a letter using starting_letter.txt
# #for each name in invited_names.txt
# #Replace the [name] placeholder with the actual name.
# #Save the letters in the folder "ReadyToSend".
#
# #Hint1: This method will help you: https://www.w3schools.com/python/ref_file_readlines.asp
#     #Hint2: This method will also help you: https://www.w3schools.com/python/ref_string_replace.asp
#         #Hint3: THis method will help you: https://www.w3schools.com/python/ref_string_strip.asp

# %%
relative_input_letter_path = './Input/Letters/starting_letter.txt'
relative_name_path = './Input/names/invited_names.txt'

# %%
with open(relative_input_letter_path) as file:
    lines = file.read()

lines
# Out:
# 'Dear [name],\n\nYou are invited to my birthday this Saturday.\n\nHope you can make it!\n\nAngela\n'

# %%
with open(relative_name_path) as file:
    name_list = file.readlines()

new_name_list = []
for name in name_list:
    new_name_list.append(name.strip())
    
new_name_list
# Out:
# ['Aang', 'Zuko', 'Appa', 'Katara', 'Sokka', 'Momo', 'Uncle Iroh', 'Toph']

# %%
for name in new_name_list:
    name_greet = lines.replace('[name]',name)
    with open(f'./output/readytosend/letter for {name}.docx',mode = 'w') as personalized_greet:
        personalized_greet.write(name_greet)
