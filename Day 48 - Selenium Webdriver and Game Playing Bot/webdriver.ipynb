# %% [markdown]
# - Selenium is a package that is used to automate web browser interactions.
#
# - Used for automated testing of web applications but is also used for automated web scraping\
#   and repetive web based tasks like taking out data from a spreadsheet and filling out a web form.
#
# - Anyhting that a user would do i.e. type,click etc. can be automated using Selenium
#
# - Like building a robot and telling it what to do on a browser.
#
# - Is compatible with all different browsers like Chrome, Safari, Edge etc.

# %%
# check if the selenium package is installed
#pip list

#if not, install the package
# pip install selenium

# %%
#the webdriver is what drives the browser and doing all the automated tasks
#webdriver serves as a bridge b/w selenium and the browser
from selenium import webdriver

# %%
#create an instance of the Chrome browser class.
# Or whatever is the browser of your choice. 
# driver = webdriver.Chrome()

# %% [markdown]
# This code errors out because Selenium's built-in manager is trying to download a ChromeDriver.\
# This is used to communicate with Chrome and do all the tasks, but the firewall is blocking it.\
# Hence, try using a third-party library instead

# %% [markdown]
# from StackOverflow: https://stackoverflow.com/questions/76453996/purpose-of-webdriver-manager/76455537#76455537
#
# Yes, when we use webdriver_manager, it helps manage the browser drivers automatically, eliminating the need for manual updates.
#
# The webdriver_manager library, such as ChromeDriverManager as you mentioned, provides a convenient way to install and manage browser drivers.\
# It downloads the appropriate driver executable for the specified browser version and operating system.
#
# The advantage of using webdriver_manager is that it can automatically check the latest version of the browser driver and download the corresponding version if needed.\
#  This ensures that your code works with the latest browser and driver versions without requiring manual intervention.
#
# Using webdriver_manager in your code simplifies the process of managing browser drivers and ensures compatibility between your code and the browser being used.

# %%
# pip install webdriver-manager


# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %% [markdown]
# This also errors out because of the firewall.
